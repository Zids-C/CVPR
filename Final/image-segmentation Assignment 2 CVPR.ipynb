# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
from PIL import Image

import tensorflow as tf
from sklearn.model_selection import train_test_split

from keras.optimizers import Adam
from keras.metrics import Recall, Precision
from keras import backend as K
from keras.layers import (Input, Conv2D, BatchNormalization, 
                          Activation, MaxPool2D, Conv2DTranspose, 
                          Concatenate)
from keras.models import Model
from keras.layers import LeakyReLU

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Name: ", tf.config.list_physical_devices('GPU'))
# Out:
# Num GPUs Available:  2
# Name:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
H = 256
W = 256
BATCH_SIZE = 8
LEARNING_RATE = 1e-4
EPOCHS = 70

DATA_PATH = '/kaggle/input/deepglobe-road-extraction-dataset/train'

# %%
smooth = 1e-15

def iou(y_true, y_pred):
    """Intersection over Union."""
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou_value = (intersection + smooth) / (union + smooth)
    return tf.ensure_shape(iou_value, shape=())

def soft_dice_coef(y_true, y_pred, smooth=1e-6):
    intersection = tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    return (2. * intersection + smooth) / (denominator + smooth)

def soft_dice_loss(y_true, y_pred):
    return 1.0 - soft_dice_coef(y_true, y_pred)

# %%
def load_data(data_path, split=0.2):
    """Load and split data into train/val/test."""
    images = sorted(glob(data_path + '/*sat.jpg'))
    masks = sorted(glob(data_path + '/*mask.png'))

    # Splitting
    train_x, val_x = train_test_split(images, test_size=0.2, random_state=42)
    train_y, val_y = train_test_split(masks, test_size=0.2, random_state=42)
    
    train_x, test_x = train_test_split(train_x, test_size=0.2, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=0.2, random_state=42)
    
    return (train_x, train_y), (val_x, val_y), (test_x, test_y)

(train_x, train_y), (val_x, val_y), (test_x, test_y) = load_data(DATA_PATH)
print(f"Train size: {len(train_x)}, Val size: {len(val_x)}, Test size: {len(test_x)}")
# Out:
# Train size: 3984, Val size: 1246, Test size: 996

# %%
def read_image(path):
    """Reads and resizes the input image."""
    try:
        img = Image.open(path)
        img = img.resize((W, H))
        x = np.array(img, dtype=np.float32) / 255.0
        return x
    except Exception as e:
        print(f'Error while reading image: {e}')
        return None

def read_mask(path):
    """Reads and resizes the input mask."""
    try:
        mask = Image.open(path).convert('L')
        mask = mask.resize((W, H))
        x = np.array(mask, dtype=np.float32) / 255.0
        x = np.expand_dims(x, axis=-1)
        return x
    except Exception as e:
        print(f'Error while reading mask: {e}')
        return None

def tf_parse(x, y):
    """Wrapper to parse images in a TensorFlow graph."""
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

# <-- ADDED: Define an augmentation function using TensorFlow ops
def random_flip(x, y):
    """
    Randomly flips the image and mask horizontally or vertically.
    """
    # Random horizontal flip
    if tf.random.uniform(()) > 0.5:
        x = tf.image.flip_left_right(x)
        y = tf.image.flip_left_right(y)

    # Random vertical flip
    if tf.random.uniform(()) > 0.5:
        x = tf.image.flip_up_down(x)
        y = tf.image.flip_up_down(y)

    return x, y

def tf_dataset(X, Y, batch=BATCH_SIZE, repeat=False, augment=False):  # <-- CHANGED
    """
    Create a TF dataset from filenames.

    Args:
        X: List of input image paths.
        Y: List of corresponding mask paths.
        batch: Batch size.
        repeat: Whether to repeat the dataset indefinitely.
        augment: Whether to apply data augmentation (flip).
    """
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    
    if augment:  # <-- ADDED
        dataset = dataset.map(random_flip, num_parallel_calls=tf.data.AUTOTUNE)

    if repeat:
        dataset = dataset.repeat()  # Repeat indefinitely for training

    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# <-- CHANGED: Pass 'augment=True' for the training dataset
train_dataset = tf_dataset(train_x, train_y, batch=BATCH_SIZE, repeat=True, augment=True)
val_dataset   = tf_dataset(val_x, val_y, batch=BATCH_SIZE, repeat=True, augment=False)

train_steps = np.ceil(len(train_x) / BATCH_SIZE).astype(int)
val_steps   = np.ceil(len(val_x) / BATCH_SIZE).astype(int)

print(f"Train steps per epoch: {train_steps}")
print(f"Validation steps per epoch: {val_steps}")
# Out:
# Train steps per epoch: 498
# Validation steps per epoch: 156

# %%
def conv_block(x, filters, kernel_size=3, activation=None, padding='same'):
    """(Conv2D -> BN -> Activation) * 2 block."""
    x = Conv2D(filters, kernel_size, padding=padding)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)  # Use LeakyReLU explicitly
    
    x = Conv2D(filters, kernel_size, padding=padding)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)  # Use LeakyReLU explicitly
    return x

def encoder_block(x, filters, activation='relu'):
    """Encoder block: conv block + maxpool."""
    c = conv_block(x, filters, activation=activation)
    p = MaxPool2D((2, 2))(c)
    return c, p

def decoder_block(x, skip_features, filters, activation='relu'):
    """Decoder block: transpose conv + concat + conv block."""
    x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(x)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, filters, activation=activation)
    return x

def build_beefy_unet(input_shape=(256, 256, 3), activation='relu'):
    """Build a beefed-up UNet with batch normalization and double conv blocks."""
    inputs = Input(input_shape)
    
    # Encoder
    c1, p1 = encoder_block(inputs, 64, activation=activation)
    c2, p2 = encoder_block(p1,   128, activation=activation)
    c3, p3 = encoder_block(p2,   256, activation=activation)
    c4, p4 = encoder_block(p3,   512, activation=activation)
    
    # Bottleneck
    bn = conv_block(p4, 1024, activation=activation)
    
    # Decoder
    d1 = decoder_block(bn, c4, 512, activation=activation)
    d2 = decoder_block(d1, c3, 256, activation=activation)
    d3 = decoder_block(d2, c2, 128, activation=activation)
    d4 = decoder_block(d3, c1, 64,  activation=activation)
    
    # Output
    outputs = Conv2D(1, (1, 1), padding='same', activation='sigmoid')(d4)
    
    model = Model(inputs, outputs)
    return model

# Instantiate and compile the model
model = build_beefy_unet(input_shape=(H, W, 3), activation=None)  # Pass None; handled internally
model.compile(
    loss=soft_dice_loss,  # <-- CHANGED: switch to Dice loss
    optimizer=Adam(LEARNING_RATE),
    metrics=[soft_dice_coef, iou, Recall(), Precision()]
)

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu (LeakyReLU)   │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ leaky_re_lu[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU) │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ leaky_re_lu_1[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU) │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ leaky_re_lu_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU) │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ leaky_re_lu_3[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU) │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ leaky_re_lu_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU) │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ leaky_re_lu_5[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 512)    │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU) │ (None, 32, 32, 512)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ leaky_re_lu_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 512)    │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU) │ (None, 32, 32, 512)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 512)    │              0 │ leaky_re_lu_7[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 16, 16, 1024)   │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 16, 16, 1024)   │          4,096 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU) │ (None, 16, 16, 1024)   │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 16, 16, 1024)   │      9,438,208 │ leaky_re_lu_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 16, 16, 1024)   │          4,096 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU) │ (None, 16, 16, 1024)   │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 512)    │      2,097,664 │ leaky_re_lu_9[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ leaky_re_lu_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 32, 32, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 32, 32, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_10            │ (None, 32, 32, 512)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 32, 32, 512)    │      2,359,808 │ leaky_re_lu_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 32, 32, 512)    │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_11            │ (None, 32, 32, 512)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 64, 256)    │        524,544 │ leaky_re_lu_11[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ leaky_re_lu_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 64, 64, 256)    │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_12            │ (None, 64, 64, 256)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ leaky_re_lu_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 64, 64, 256)    │          1,024 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_13            │ (None, 64, 64, 256)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 128)  │        131,200 │ leaky_re_lu_13[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ leaky_re_lu_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 128, 128, 128)  │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 128, 128, 128)  │            512 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_14            │ (None, 128, 128, 128)  │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 128, 128, 128)  │        147,584 │ leaky_re_lu_14[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 128, 128, 128)  │            512 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_15            │ (None, 128, 128, 128)  │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 256, 256, 64)   │         32,832 │ leaky_re_lu_15[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ leaky_re_lu_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 256, 256, 64)   │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 256, 256, 64)   │            256 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_16            │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ leaky_re_lu_16[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 256, 256, 64)   │            256 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_17            │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ leaky_re_lu_17[0][0]   │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,055,297 (118.47 MB)
#  Trainable params: 31,043,521 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
for batch_idx, (xx, yy) in enumerate(train_dataset.take(1)):
    print("Batch", batch_idx)
    print("X shape:", xx.shape, xx.dtype)
    print("Y shape:", yy.shape, yy.dtype)
# Out:
# Batch 0
# X shape: (8, 256, 256, 3) <dtype: 'float32'>
# Y shape: (8, 256, 256, 1) <dtype: 'float32'>

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_recall',
        factor=0.1,
        patience=2,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_recall',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )
]

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_data=val_dataset,
    validation_steps=val_steps,
    callbacks=callbacks   # <-- ADDED
)
# Out:
# Epoch 1/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 355s 592ms/step - iou: 0.1504 - loss: 0.7854 - precision: 0.1985 - recall: 0.6633 - soft_dice_coef: 0.2146 - val_iou: 0.2417 - val_loss: 0.6902 - val_precision: 0.6603 - val_recall: 0.2760 - val_soft_dice_coef: 0.3098 - learning_rate: 1.0000e-04
# Epoch 2/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 605ms/step - iou: 0.3475 - loss: 0.5438 - precision: 0.6024 - recall: 0.5328 - soft_dice_coef: 0.4562 - val_iou: 0.3691 - val_loss: 0.4962 - val_precision: 0.6949 - val_recall: 0.4725 - val_soft_dice_coef: 0.5038 - learning_rate: 1.0000e-04
# Epoch 3/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - iou: 0.4016 - loss: 0.4553 - precision: 0.7028 - recall: 0.5232 - soft_dice_coef: 0.5447
# Epoch 3: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 300s 602ms/step - iou: 0.4016 - loss: 0.4553 - precision: 0.7028 - recall: 0.5232 - soft_dice_coef: 0.5447 - val_iou: 0.3747 - val_loss: 0.4742 - val_precision: 0.8226 - val_recall: 0.3898 - val_soft_dice_coef: 0.5258 - learning_rate: 1.0000e-04
# Epoch 4/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 300s 604ms/step - iou: 0.4421 - loss: 0.4050 - precision: 0.7637 - recall: 0.5363 - soft_dice_coef: 0.5950 - val_iou: 0.4440 - val_loss: 0.4013 - val_precision: 0.7763 - val_recall: 0.5343 - val_soft_dice_coef: 0.5987 - learning_rate: 1.0000e-05
# Epoch 5/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - iou: 0.4544 - loss: 0.3924 - precision: 0.7698 - recall: 0.5493 - soft_dice_coef: 0.6076
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 300s 603ms/step - iou: 0.4544 - loss: 0.3924 - precision: 0.7698 - recall: 0.5493 - soft_dice_coef: 0.6076 - val_iou: 0.4475 - val_loss: 0.3972 - val_precision: 0.7796 - val_recall: 0.5372 - val_soft_dice_coef: 0.6028 - learning_rate: 1.0000e-05
# Epoch 6/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 604ms/step - iou: 0.4590 - loss: 0.3872 - precision: 0.7676 - recall: 0.5606 - soft_dice_coef: 0.6128 - val_iou: 0.4553 - val_loss: 0.3895 - val_precision: 0.7771 - val_recall: 0.5519 - val_soft_dice_coef: 0.6105 - learning_rate: 1.0000e-06
# Epoch 7/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - iou: 0.4617 - loss: 0.3846 - precision: 0.7767 - recall: 0.5550 - soft_dice_coef: 0.6154
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 300s 603ms/step - iou: 0.4617 - loss: 0.3846 - precision: 0.7767 - recall: 0.5550 - soft_dice_coef: 0.6154 - val_iou: 0.4567 - val_loss: 0.3882 - val_precision: 0.7807 - val_recall: 0.5506 - val_soft_dice_coef: 0.6118 - learning_rate: 1.0000e-06
# Epoch 8/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 300s 602ms/step - iou: 0.4622 - loss: 0.3840 - precision: 0.7753 - recall: 0.5574 - soft_dice_coef: 0.6160 - val_iou: 0.4553 - val_loss: 0.3894 - val_precision: 0.7838 - val_recall: 0.5464 - val_soft_dice_coef: 0.6106 - learning_rate: 1.0000e-07
# Epoch 9/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - iou: 0.4625 - loss: 0.3838 - precision: 0.7765 - recall: 0.5567 - soft_dice_coef: 0.6162
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 605ms/step - iou: 0.4625 - loss: 0.3838 - precision: 0.7765 - recall: 0.5567 - soft_dice_coef: 0.6162 - val_iou: 0.4563 - val_loss: 0.3886 - val_precision: 0.7848 - val_recall: 0.5459 - val_soft_dice_coef: 0.6114 - learning_rate: 1.0000e-07
# Epoch 10/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 605ms/step - iou: 0.4633 - loss: 0.3831 - precision: 0.7786 - recall: 0.5559 - soft_dice_coef: 0.6169 - val_iou: 0.4565 - val_loss: 0.3883 - val_precision: 0.7847 - val_recall: 0.5456 - val_soft_dice_coef: 0.6117 - learning_rate: 1.0000e-08
# Epoch 11/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - iou: 0.4629 - loss: 0.3834 - precision: 0.7785 - recall: 0.5555 - soft_dice_coef: 0.6166
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 604ms/step - iou: 0.4629 - loss: 0.3834 - precision: 0.7785 - recall: 0.5555 - soft_dice_coef: 0.6166 - val_iou: 0.4567 - val_loss: 0.3882 - val_precision: 0.7843 - val_recall: 0.5458 - val_soft_dice_coef: 0.6118 - learning_rate: 1.0000e-08
# Epoch 12/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 605ms/step - iou: 0.4634 - loss: 0.3830 - precision: 0.7792 - recall: 0.5559 - soft_dice_coef: 0.6170 - val_iou: 0.4554 - val_loss: 0.3893 - val_precision: 0.7848 - val_recall: 0.5456 - val_soft_dice_coef: 0.6107 - learning_rate: 1.0000e-09
# Epoch 13/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - iou: 0.4633 - loss: 0.3830 - precision: 0.7786 - recall: 0.5559 - soft_dice_coef: 0.6170
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 605ms/step - iou: 0.4633 - loss: 0.3830 - precision: 0.7786 - recall: 0.5559 - soft_dice_coef: 0.6170 - val_iou: 0.4561 - val_loss: 0.3887 - val_precision: 0.7844 - val_recall: 0.5459 - val_soft_dice_coef: 0.6113 - learning_rate: 1.0000e-09
# Epoch 14/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 604ms/step - iou: 0.4626 - loss: 0.3837 - precision: 0.7779 - recall: 0.5553 - soft_dice_coef: 0.6163 - val_iou: 0.4564 - val_loss: 0.3885 - val_precision: 0.7843 - val_recall: 0.5459 - val_soft_dice_coef: 0.6115 - learning_rate: 1.0000e-10
# Epoch 15/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - iou: 0.4628 - loss: 0.3835 - precision: 0.7780 - recall: 0.5556 - soft_dice_coef: 0.6165
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 300s 603ms/step - iou: 0.4628 - loss: 0.3835 - precision: 0.7780 - recall: 0.5556 - soft_dice_coef: 0.6165 - val_iou: 0.4568 - val_loss: 0.3881 - val_precision: 0.7839 - val_recall: 0.5464 - val_soft_dice_coef: 0.6119 - learning_rate: 1.0000e-10
# Epoch 16/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 604ms/step - iou: 0.4627 - loss: 0.3836 - precision: 0.7781 - recall: 0.5553 - soft_dice_coef: 0.6164 - val_iou: 0.4553 - val_loss: 0.3894 - val_precision: 0.7849 - val_recall: 0.5452 - val_soft_dice_coef: 0.6106 - learning_rate: 1.0000e-11
# Epoch 17/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - iou: 0.4625 - loss: 0.3838 - precision: 0.7771 - recall: 0.5558 - soft_dice_coef: 0.6162
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999092680235e-13.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 300s 602ms/step - iou: 0.4625 - loss: 0.3838 - precision: 0.7771 - recall: 0.5558 - soft_dice_coef: 0.6162 - val_iou: 0.4557 - val_loss: 0.3892 - val_precision: 0.7848 - val_recall: 0.5452 - val_soft_dice_coef: 0.6108 - learning_rate: 1.0000e-11
# Epoch 18/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 605ms/step - iou: 0.4626 - loss: 0.3837 - precision: 0.7776 - recall: 0.5559 - soft_dice_coef: 0.6163 - val_iou: 0.4563 - val_loss: 0.3886 - val_precision: 0.7852 - val_recall: 0.5450 - val_soft_dice_coef: 0.6114 - learning_rate: 1.0000e-12
# Epoch 19/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - iou: 0.4630 - loss: 0.3833 - precision: 0.7784 - recall: 0.5556 - soft_dice_coef: 0.6167
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.9999988758398e-14.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 605ms/step - iou: 0.4630 - loss: 0.3833 - precision: 0.7784 - recall: 0.5556 - soft_dice_coef: 0.6167 - val_iou: 0.4570 - val_loss: 0.3879 - val_precision: 0.7843 - val_recall: 0.5460 - val_soft_dice_coef: 0.6121 - learning_rate: 1.0000e-12
# Epoch 20/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 604ms/step - iou: 0.4637 - loss: 0.3826 - precision: 0.7791 - recall: 0.5563 - soft_dice_coef: 0.6174 - val_iou: 0.4554 - val_loss: 0.3893 - val_precision: 0.7841 - val_recall: 0.5463 - val_soft_dice_coef: 0.6107 - learning_rate: 1.0000e-13
# Epoch 21/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - iou: 0.4628 - loss: 0.3835 - precision: 0.7783 - recall: 0.5554 - soft_dice_coef: 0.6165
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999146890344e-15.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 604ms/step - iou: 0.4628 - loss: 0.3835 - precision: 0.7783 - recall: 0.5553 - soft_dice_coef: 0.6165 - val_iou: 0.4561 - val_loss: 0.3888 - val_precision: 0.7850 - val_recall: 0.5455 - val_soft_dice_coef: 0.6112 - learning_rate: 1.0000e-13
# Epoch 22/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 604ms/step - iou: 0.4630 - loss: 0.3833 - precision: 0.7795 - recall: 0.5553 - soft_dice_coef: 0.6167 - val_iou: 0.4564 - val_loss: 0.3885 - val_precision: 0.7848 - val_recall: 0.5454 - val_soft_dice_coef: 0.6115 - learning_rate: 1.0000e-14
# Epoch 23/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - iou: 0.4636 - loss: 0.3828 - precision: 0.7793 - recall: 0.5560 - soft_dice_coef: 0.6172
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999998977483753e-16.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 605ms/step - iou: 0.4636 - loss: 0.3828 - precision: 0.7793 - recall: 0.5560 - soft_dice_coef: 0.6172 - val_iou: 0.4570 - val_loss: 0.3879 - val_precision: 0.7841 - val_recall: 0.5460 - val_soft_dice_coef: 0.6121 - learning_rate: 1.0000e-14
# Epoch 24/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 605ms/step - iou: 0.4633 - loss: 0.3831 - precision: 0.7784 - recall: 0.5557 - soft_dice_coef: 0.6169 - val_iou: 0.4554 - val_loss: 0.3893 - val_precision: 0.7847 - val_recall: 0.5458 - val_soft_dice_coef: 0.6107 - learning_rate: 1.0000e-15
# Epoch 25/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - iou: 0.4631 - loss: 0.3832 - precision: 0.7785 - recall: 0.5555 - soft_dice_coef: 0.6168
# Epoch 25: ReduceLROnPlateau reducing learning rate to 9.999998977483754e-17.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 301s 604ms/step - iou: 0.4631 - loss: 0.3832 - precision: 0.7785 - recall: 0.5555 - soft_dice_coef: 0.6168 - val_iou: 0.4559 - val_loss: 0.3889 - val_precision: 0.7850 - val_recall: 0.5451 - val_soft_dice_coef: 0.6111 - learning_rate: 1.0000e-15
# Epoch 26/70
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 302s 606ms/step - iou: 0.4632 - loss: 0.3831 - precision: 0.7787 - recall: 0.5558 - soft_dice_coef: 0.6169 - val_iou: 0.4564 - val_loss: 0.3884 - val_precision: 0.7848 - val_recall: 0.5455 - val_soft_dice_coef: 0.6116 - learning_rate: 1.0000e-16
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %%
model.save('v5_road_extraction_beefy_unet.h5')
print("Model saved as road_extraction_beefy_unet.h5")
# Out:
# Model saved as road_extraction_beefy_unet.h5

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# Select 5 random images from the test dataset
random_image_paths = random.sample(test_x, 5)

# Create a figure to display the images and predictions
plt.figure(figsize=(15, 10))

# Loop through the selected images
for i, sample_image_path in enumerate(random_image_paths):
    # Read the image
    sample_img = read_image(sample_image_path)
    if sample_img is not None:
        # Expand dimensions for model input
        sample_img_expanded = np.expand_dims(sample_img, axis=0)
        
        # Make prediction
        prediction = model.predict(sample_img_expanded)[0]
        
        # Plot the original image
        plt.subplot(5, 2, 2 * i + 1)
        plt.imshow(sample_img)
        plt.title(f'Original Image {i + 1}')
        plt.axis('off')
        
        # Plot the predicted mask
        plt.subplot(5, 2, 2 * i + 2)
        plt.imshow(prediction.squeeze(), cmap='gray')
        plt.title(f'Predicted Mask {i + 1}')
        plt.axis('off')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Use the actual number of epochs that were run:
epochs_ran = len(training_loss)

plt.figure(figsize=(8, 5))
plt.plot(range(1, epochs_ran + 1), training_loss, label='Training Loss')
plt.plot(range(1, epochs_ran + 1), validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.show()
